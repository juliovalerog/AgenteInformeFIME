# %%
import pandas as pd
import langgraph  # noqa: F401

print("OK: pandas", pd.__version__)
print("OK: langgraph import")
# Out:
# OK: pandas 2.3.3
# OK: langgraph import

# %%
import sys, site
print(sys.executable)
print(sys.version)
print(site.getsitepackages())
# Out:
# c:\Users\julio\OneDrive\Documentos\Clases\Ficheros para clase\BrainCode\FIME\FIME Proficiency\Modelos de razonamiento\AgenteInformeFIME\.venv\Scripts\python.exe
# 3.12.9 (tags/v3.12.9:fdb8142, Feb  4 2025, 15:27:58) [MSC v.1942 64 bit (AMD64)]
# ['c:\\Users\\julio\\OneDrive\\Documentos\\Clases\\Ficheros para clase\\BrainCode\\FIME\\FIME Proficiency\\Modelos de razonamiento\\AgenteInformeFIME\\.venv', 'c:\\Users\\julio\\OneDrive\\Documentos\\Clases\\Ficheros para clase\\BrainCode\\FIME\\FIME Proficiency\\Modelos de razonamiento\\AgenteInformeFIME\\.venv\\Lib\\site-packages']

# %%
import pandas as pd
import numpy as np
import requests
import bs4
print("ok")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import requests
#
# ModuleNotFoundError: No module named 'pandas'
